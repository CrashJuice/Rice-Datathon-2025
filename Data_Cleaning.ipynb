# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('combined_new_2.csv')

# drop State and County (for merging purposes)
df_numeric = df.drop(columns=['State', 'County'], errors='ignore')

# correlation matrix
corr_matrix = df_numeric.corr()

# heatmap
plt.figure(figsize=(12, 8))
mask = np.eye(len(corr_matrix))  # mask for the diagonal
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', linewidths=0.5, mask=mask)
plt.title('Correlation Heatmap')
plt.show()

# %%
# most correlated feature pairs
corr_unstacked = corr_matrix.unstack()
corr_sorted = corr_unstacked.sort_values(ascending=False)
corr_filtered = corr_sorted[corr_sorted < 1].drop_duplicates()

#top correlated feature pairs
print(corr_filtered.head(15))
# Out:
# PCT_NHASIAN10       MEDHHINC15            0.841871
# PCT_SNAP17          PCT_WIC17             0.721684
# PCT_NHASIAN10       RECFACPTH16           0.634191
#                     FFRPTH16              0.602998
# PCT_NHBLACK10       POVRATE15             0.584721
# RECFACPTH16         MEDHHINC15            0.563678
# GROCPTH16           WICSPTH16             0.560973
# PCT_WIC17           FOODINSEC_15_17       0.545838
# FOODINSEC_15_17     PCT_SNAP17            0.543403
# PCT_SNAP17          PCT_OBESE_ADULTS17    0.521468
# PCT_LACCESS_LOWI15  PCT_LACCESS_HHNV15    0.501683
# PCT_65OLDER10       PCT_NHWHITE10         0.501403
# FFRPTH16            MEDHHINC15            0.500974
# PCT_OBESE_ADULTS17  PCT_WIC17             0.500237
# RECFACPTH16         FFRPTH16              0.487402
# dtype: float64
